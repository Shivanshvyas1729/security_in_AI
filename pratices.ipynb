# %%
print("all okay")
# Out:
# all okay

# %%
import os, warnings 
warnings.filterwarnings("ignore")
from dotenv import load_dotenv

load_dotenv(override=True)
# Out:
# True

# %%
print("LANGSMITH_TRACING :", os.getenv("LANGSMITH_TRACING", "not set"))
print("LANGSMITH_API_KEY :", "✅" if os.getenv("LANGSMITH_API_KEY") else "❌  missing")
print("LANGSMITH_PROJECT :", os.getenv("LANGSMITH_PROJECT", "default"))
print("GROQ_API_KEY      :", "✅" if os.getenv("GROQ_API_KEY")      else "❌  missing")
print("GEMINI_API_KEY    :", "✅" if os.getenv("GEMINI_API_KEY")    else "❌  missing")
# Out:
# LANGSMITH_TRACING : true
# LANGSMITH_API_KEY : ✅
# LANGSMITH_PROJECT : udemy
# GROQ_API_KEY      : ✅
# GEMINI_API_KEY    : ✅

# %%
from langchain_groq import ChatGroq 


llm  = ChatGroq(model= "openai/gpt-oss-120b",temperature=0.3)


response = llm.invoke("what is humnoid")

print(response.content)
# Out:
# **Humanoid** (pronounced /ˈhjuːmənɔɪd/) is an adjective and noun used to describe anything that has a shape, appearance, or characteristics that resemble a human being. The word comes from the Latin *humānus* (“human”) and the Greek suffix *‑oid* (“like” or “resembling”).
#
# ---
#
# ## 1. General Meaning
#
# | Aspect | What “humanoid” means |
# |--------|-----------------------|
# | **Physical form** | A body plan with a head, torso, two arms, and two legs (or at least the suggestion of that layout). |
# | **Behavioral traits** | May include gestures, facial expressions, speech, or other actions that we associate with people. |
# | **Scope** | Applies to living organisms, machines, fictional creatures, and artistic representations. |
#
# ---
#
# ## 2. Common Contexts
#
# | Context | Example | Why it’s called “humanoid” |
# |---------|---------|----------------------------|
# | **Robotics** | *ASIMO* (Honda), *Atlas* (Boston Dynamics), *Sophia* (Hanson Robotics) | Robots built with a human‑like skeleton, limbs, and sometimes a face. |
# | **Science‑fiction & Fantasy** | Androids in *Star Trek*, the *C-3PO* droid in *Star Wars*, the *Elder Scrolls* “humanoid races” (e.g., elves, dwarves) | Creatures that look or act like people, even if they’re alien or magical. |
# | **Biology / Anthropology** | *Homo sapiens* (our species) is the ultimate humanoid; some extinct hominins (Neanderthals, Homo erectus) are also described as humanoid. | They share the basic human body plan. |
# | **Art & Design** | Statues, cartoons, video‑game avatars, emojis (e.g., the “person” emoji) | The visual representation mimics a human silhouette. |
# | **Psychology / Cognitive Science** | Studies of “humanoid perception” (how we attribute mind to robot faces) | The term is used to discuss how human‑like features affect our attitudes. |
#
# ---
#
# ## 3. Humanoid vs. Related Terms
#
# | Term | Definition | Key Difference |
# |------|------------|----------------|
# | **Human** | The biological species *Homo sapiens*. | Strictly biological; “humanoid” can be non‑biological. |
# | **Anthropoid** | Often used for primates (e.g., apes) or for “human‑like” in a broader sense. | More about evolutionary lineage; “humanoid” focuses on shape/appearance. |
# | **Android** | A robot or synthetic being that looks like a human, especially with a realistic face. | All androids are humanoid, but not all humanoids are androids (e.g., a cartoon character). |
# | **Cyborg** | A being that is part biological, part machine. | May be humanoid, but the term emphasizes the hybrid nature. |
# | **Gynoid** | A female‑styled humanoid robot. | Gender‑specific subset of humanoid. |
# | **Biorobot** | A robot that incorporates living tissue. | Could be humanoid, but the term stresses the biological component. |
#
# ---
#
# ## 4. Why Humanoids Matter
#
# 1. **Human‑Robot Interaction (HRI)**
#    - *Familiarity*: People find it easier to communicate with machines that look like them.
#    - *Trust & Comfort*: Studies show that a moderate level of human likeness (the “uncanny valley” effect) can increase trust, but too much realism can cause discomfort.
#
# 2. **Design & Engineering**
#    - *Balance & Locomotion*: Replicating bipedal walking is a major engineering challenge; humanoid robots help us understand human biomechanics.
#    - *Tool Use*: Human‑shaped arms and hands can manipulate everyday objects without redesigning the environment.
#
# 3. **Cultural & Narrative Impact**
#    - Humanoids populate myths (e.g., golems, automata), literature (e.g., Mary Shelley’s *Frankenstein*), and modern media, shaping how societies think about identity, consciousness, and ethics.
#
# 4. **Ethical & Legal Questions**
#    - Rights for sentient humanoid AI?
#    - Liability when a humanoid robot causes injury.
#    - Representation and bias (e.g., gendered humanoid designs).
#
# ---
#
# ## 5. A Quick Primer on Humanoid Robotics
#
# | Feature | Typical Implementation | Challenges |
# |---------|-----------------------|------------|
# | **Skeleton / Frame** | Aluminum, carbon‑fiber, or titanium exoskeletons; often modular. | Weight vs. strength trade‑off; maintaining balance. |
# | **Actuators** | Electric servomotors, pneumatic cylinders, or newer soft‑actuators. | Power consumption, noise, smoothness of motion. |
# | **Sensors** | IMUs (inertial measurement units), force/torque sensors, cameras, LIDAR. | Sensor fusion, latency, perception in cluttered environments. |
# | **Control Algorithms** | Central pattern generators, model‑based control, reinforcement learning. | Real‑time computation, stability under disturbances. |
# | **Power** | Batteries (Li‑ion, Li‑Po), tethered power, emerging fuel‑cell tech. | Energy density, runtime, heat management. |
# | **Human‑like Appearance** | Silicone skin, 3D‑printed facial features, LED eyes. | The “uncanny valley,” durability, hygiene. |
#
# *Notable examples*
# - **ASIMO (Honda)** – early bipedal robot with smooth walking and hand gestures.
# - **Atlas (Boston Dynamics)** – highly dynamic, can run, jump, and do backflips.
# - **Pepper (SoftBank Robotics)** – a socially interactive humanoid with a stylized, non‑realistic face.
# - **Sophia (Hanson Robotics)** – a media‑focused gynoid with expressive facial muscles.
#
# ---
#
# ## 6. Fun Fact
#
# The term **“humanoid”** was popularized in the 1950s–60s during the early days of science‑fiction literature and early robotics research. It appears in the title of the classic 1955 novel *The Humanoids* by Jack Williamson, which imagined massive, human‑shaped machines that enforced a “law of non‑interference” on humanity.
#
# ---
#
# ### TL;DR
#
# A **humanoid** is anything—robot, creature, or representation—that looks or behaves like a human, typically featuring a head, torso, two arms, and two legs. The concept spans engineering (humanoid robots), fiction (androids, alien races), biology (our own species and close relatives), and art. Its importance lies in how human‑like form influences interaction, design challenges, cultural storytelling, and emerging ethical debates.

# %%
import os 
os.gete
